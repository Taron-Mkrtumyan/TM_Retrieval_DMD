# %% [markdown]
# # 01 — Data Acquisition
# Generate random binary DMD patterns and record camera frames.

# %%
import numpy as np
from src.acquisition import acquire_dataset

N = 256  # number of macropixels
M = 4 * N  # number of patterns
K = 20   # test patterns

patterns = np.random.randint(0, 2, size=(M + K, N))
train_patterns = patterns[:M]
test_patterns  = patterns[M:]

# frames = acquire_dataset(train_patterns)
# test_frames = acquire_dataset(test_patterns)
