# %% [markdown]
# # 03 — Parametric Study: Oversampling Ratio
# Retrieve TM for M = N, 2N, 4N and evaluate Pearson correlation.

# %%
import numpy as np
import matplotlib.pyplot as plt
from src.tm_retrieval import gs_retrieve_tm
from src.validation import evaluate

N = 256
ratios = [1, 2, 4]
results = {}

for r in ratios:
    M = r * N
    # TM = gs_retrieve_tm(train_patterns[:M], frames[:M], n_modes=64)
    # mean_r, _ = evaluate(TM, test_patterns, test_frames)
    # results[r] = mean_r
    pass

# plt.plot(ratios, [results[r] for r in ratios], 'o-')
# plt.xlabel('Oversampling ratio M/N')
# plt.ylabel('Pearson correlation')
# plt.title('TM retrieval accuracy vs. oversampling')
# plt.savefig('results/figures/oversampling_study.png', dpi=150)
