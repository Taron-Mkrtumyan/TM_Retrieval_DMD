# %% [markdown]
# # 04 — PSF Engineering (Bonus)
# Use the retrieved TM to shape the output into a target spatial mode.

# %%
import numpy as np
import matplotlib.pyplot as plt
from src.psf_engineering import compute_input_field, binarize, mode_overlap

# TM = np.load('results/tm_retrieved.npy')

# Define your target mode (e.g. donut shape) here
# target_field = ...

# input_field  = compute_input_field(TM, target_field)
# dmd_pattern  = binarize(input_field)

# Display dmd_pattern on DMD and capture output
# overlap = mode_overlap(measured_output, np.abs(target_field)**2)
# print(f'Mode overlap: {overlap:.4f}')
