# %% [markdown]
# # 02 — TM Retrieval
# Run the GS algorithm and save the retrieved TM.

# %%
import numpy as np
from src.tm_retrieval import gs_retrieve_tm

# Load your data here
# train_patterns = np.load('data/patterns/train_patterns.npy')
# frames         = np.load('data/raw/train_frames.npy')

# TM = gs_retrieve_tm(train_patterns, frames, n_modes=64)
# np.save('results/tm_retrieved.npy', TM)
